# %% [markdown]
# ## New workflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 90

# %%
hospital_data = pd.read_csv('data01.csv')
hospital_data.head(100)
# Out:
#     group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0       1  125047      0.0   72        1  37.588179             0
# 1       1  139812      0.0   75        2        NaN             0
# 2       1  109787      0.0   83        2  26.572634             0
# 3       1  130587      0.0   43        2  83.264629             0
# 4       1  138290      0.0   75        2  31.824842             1
# ..    ...     ...      ...  ...      ...        ...           ...
# 95      1  152651      0.0   94        1  26.224800             1
# 96      1  128156      0.0   70        1  25.662222             0
# 97      1  108287      0.0   63        2  37.261470             1
# 98      1  135809      0.0   68        1  34.527089             1
# 99      1  121435      0.0   88        1  14.858018             1
#
#     atrialfibrillation  CHD with no MI  diabetes  deficiencyanemias  \
# 0                    0               0         1                  1
# ...

# %%
hospital_data.drop('ID', axis=1,inplace=True)

# %%
hospital_data
# Out:
#       outcome  age  gendera        BMI  hypertensive  atrialfibrillation  \
# 0         0.0   72        1  37.588179             0                   0
# 1         0.0   75        2        NaN             0                   0
# 2         0.0   83        2  26.572634             0                   0
# 3         0.0   43        2  83.264629             0                   0
# 4         0.0   75        2  31.824842             1                   0
# ...       ...  ...      ...        ...           ...                 ...
# 1172      0.0   62        1  25.516870             1                   1
# 1173      0.0   78        1  25.822710             0                   1
# 1174      0.0   85        2  23.891779             1                   1
# 1175      0.0   79        2  35.288554             0                   0
# 1176      0.0   47        1  23.121384             1                   0
#
#       CHD with no MI  diabetes  deficiencyanemias  depression  Hyperlipemia  \
# ...

# %%
hospital_data.describe()
# Out:
#            outcome          age      gendera         BMI  hypertensive  \
# count  1176.000000  1177.000000  1177.000000  962.000000   1177.000000
# mean      0.135204    74.055225     1.525064   30.188278      0.717927
# std       0.342087    13.434061     0.499584    9.325997      0.450200
# min       0.000000    19.000000     1.000000   13.346801      0.000000
# 25%       0.000000    65.000000     1.000000   24.326461      0.000000
# 50%       0.000000    77.000000     2.000000   28.312474      1.000000
# 75%       0.000000    85.000000     2.000000   33.633509      1.000000
# max       1.000000    99.000000     2.000000  104.970366      1.000000
#
#        atrialfibrillation  CHD with no MI     diabetes  deficiencyanemias  \
# count         1177.000000     1177.000000  1177.000000        1177.000000
# mean             0.451147        0.085811     0.421410           0.338997
# std              0.497819        0.280204     0.493995           0.473570
# ...

# %%
hospital_data.isna().sum()
# Out:
# outcome                       1
# age                           0
# gendera                       0
# BMI                         215
# hypertensive                  0
# atrialfibrillation            0
# CHD with no MI                0
# diabetes                      0
# deficiencyanemias             0
# depression                    0
# Hyperlipemia                  0
# Renal failure                 0
# COPD                          0
# heart rate                   13
# Systolic blood pressure      16
# Diastolic blood pressure     16
# Respiratory rate             13
# temperature                  19
# SP O2                        13
# Urine output                 36
# hematocrit                    0
# RBC                           0
# MCH                           0
# MCHC                          0
# MCV                           0
# RDW                           0
# Leucocyte                     0
# Platelets                     0
# Neutrophils                 144
# ...

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   outcome                   1176 non-null   float64
#  1   age                       1177 non-null   int64
#  2   gendera                   1177 non-null   int64
#  3   BMI                       962 non-null    float64
#  4   hypertensive              1177 non-null   int64
#  5   atrialfibrillation        1177 non-null   int64
#  6   CHD with no MI            1177 non-null   int64
#  7   diabetes                  1177 non-null   int64
#  8   deficiencyanemias         1177 non-null   int64
#  9   depression                1177 non-null   int64
#  10  Hyperlipemia              1177 non-null   int64
#  11  Renal failure             1177 non-null   int64
#  12  COPD                      1177 non-null   int64
#  13  heart rate                1164 non-null   float64
# ...

# %%
hospital_data.outcome.value_counts()
# Out:
# 0.0    1017
# 1.0     159
# Name: outcome, dtype: int64

# %%
hospital_data.outcome.value_counts().plot(kind='bar', color=['green', 'cyan'])
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(hospital_data.gendera, hospital_data.outcome)
# Out:
# outcome  0.0  1.0
# gendera
# 1        478   80
# 2        539   79

# %%
hospital_data['Urine output'].value_counts()
# Out:
# 2155.0    6
# 1305.0    6
# 930.0     5
# 860.0     5
# 1495.0    5
#          ..
# 2870.0    1
# 978.0     1
# 1925.0    1
# 2855.0    1
# 118.0     1
# Name: Urine output, Length: 810, dtype: int64

# %%
hospital_data['hematocrit'].plot(style='.')
# Out:
# <AxesSubplot:>

# %%
hospital_data.age.plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Lets fill the missing numbers with the mean

# %%
from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer

# %%
fill = SimpleImputer(strategy='mean')
columns = ['Urine Output']

imputer = fill.fit_transform(hospital_data)

# %%
# Out:
# array([[ 0.        , 72.        ,  1.        , ...,  0.5       ,
#         40.        , 55.        ],
#        [ 0.        , 75.        ,  2.        , ...,  0.5       ,
#         78.        , 55.        ],
#        [ 0.        , 83.        ,  2.        , ...,  0.5       ,
#         71.5       , 35.        ],
#        ...,
#        [ 0.        , 85.        ,  2.        , ...,  1.85342557,
#         45.53538235, 55.        ],
#        [ 0.        , 79.        ,  2.        , ...,  1.85342557,
#         45.53538235, 25.        ],
#        [ 0.        , 47.        ,  1.        , ...,  1.85342557,
#         45.53538235, 55.        ]])

# %%
# Out:
# outcome                       1
# age                           0
# gendera                       0
# BMI                         215
# hypertensive                  0
# atrialfibrillation            0
# CHD with no MI                0
# diabetes                      0
# deficiencyanemias             0
# depression                    0
# Hyperlipemia                  0
# Renal failure                 0
# COPD                          0
# heart rate                   13
# Systolic blood pressure      16
# Diastolic blood pressure     16
# Respiratory rate             13
# temperature                  19
# SP O2                        13
# Urine output                 36
# hematocrit                    0
# RBC                           0
# MCH                           0
# MCHC                          0
# MCV                           0
# RDW                           0
# Leucocyte                     0
# Platelets                     0
# Neutrophils                 144
# ...

# %%
hospital_data['BMI'].fillna(hospital_data['Urine output'].mean(), inplace=True)

# %%
def fill(a):
    c = a.fillna(a.mean(), inplace=True)
    return c

fill(hospital_data['PCO2'])

# %%
hospital_data.dropna(subset='outcome', inplace=True)

# %%
hospital_data
# Out:
#       outcome  age  gendera        BMI  hypertensive  atrialfibrillation  \
# 0         0.0   72        1  37.588179             0                   0
# 1         0.0   75        2  30.188278             0                   0
# 2         0.0   83        2  26.572634             0                   0
# 3         0.0   43        2  83.264629             0                   0
# 4         0.0   75        2  31.824842             1                   0
# ...       ...  ...      ...        ...           ...                 ...
# 1172      0.0   62        1  25.516870             1                   1
# 1173      0.0   78        1  25.822710             0                   1
# 1174      0.0   85        2  23.891779             1                   1
# 1175      0.0   79        2  35.288554             0                   0
# 1176      0.0   47        1  23.121384             1                   0
#
#       CHD with no MI  diabetes  deficiencyanemias  depression  Hyperlipemia  \
# ...

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 0 to 1176
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   outcome                   1176 non-null   float64
#  1   age                       1176 non-null   int64
#  2   gendera                   1176 non-null   int64
#  3   BMI                       1176 non-null   float64
#  4   hypertensive              1176 non-null   int64
#  5   atrialfibrillation        1176 non-null   int64
#  6   CHD with no MI            1176 non-null   int64
#  7   diabetes                  1176 non-null   int64
#  8   deficiencyanemias         1176 non-null   int64
#  9   depression                1176 non-null   int64
#  10  Hyperlipemia              1176 non-null   int64
#  11  Renal failure             1176 non-null   int64
#  12  COPD                      1176 non-null   int64
#  13  heart rate                1176 non-null   float64
# ...
